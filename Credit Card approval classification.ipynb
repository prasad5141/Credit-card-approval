# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1    ?  40.83  3.500       u            g              i        bb
# 1    2    ?  32.25  1.500       u            g              c         v
# 2    3    ?  28.17  0.585       u            g             aa         v
# 3    4    ?  29.75  0.665       u            g              w         v
# 4    5    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#   ZipCode  Income Approved
# 0    1160       0        -
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 17 columns):
# Key               590 non-null int64
# Male              590 non-null object
# Age               590 non-null object
# Debt              590 non-null float64
# Married           590 non-null object
# BankCustomer      590 non-null object
# EducationLevel    590 non-null object
# Ethnicity         590 non-null object
# YearsEmployed     590 non-null float64
# PriorDefault      590 non-null object
# Employed          590 non-null object
# CreditScore       590 non-null int64
# DriversLicense    590 non-null object
# Citizen           590 non-null object
# ZipCode           590 non-null object
# Income            590 non-null int64
# Approved          590 non-null object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 78.5+ KB

# %%
data['Approved'].value_counts()
# Out:
# -    358
# +    232
# Name: Approved, dtype: int64

# %%
data['Male'].value_counts()
# Out:
# b    400
# a    179
# ?     11
# Name: Male, dtype: int64

# %%
# analysing all data categorical variables 
for column in data.columns:
    if (column != 'Key') and (column != 'Debt') and (column != 'Age') and (column != 'YearsEmployed') and (column != 'ZipCode') and (column != 'Income'):
        print(column)
        print(data[column].value_counts())
        print('\n')
# Out:
# Male
# b    400
# a    179
# ?     11
# Name: Male, dtype: int64
#
#
# Married
# u    434
# y    148
# ?      6
# l      2
# Name: Married, dtype: int64
#
#
# BankCustomer
# g     434
# p     148
# ?       6
# gg      2
# Name: BankCustomer, dtype: int64
#
#
# EducationLevel
# c     119
# q      65
# i      53
# w      51
# aa     50
# ff     49
# k      45
# x      33
# m      30
# cc     29
# d      24
# e      21
# j      10
# ?       9
# r       2
# Name: EducationLevel, dtype: int64
#
#
# Ethnicity
# v     341
# h     104
# bb     55
# ff     53
# ?       9
# j       8
# z       8
# dd      6
# n       4
# o       2
# Name: Ethnicity, dtype: int64
#
#
# PriorDefault
# f    299
# t    291
# Name: PriorDefault, dtype: int64
#
#
# Employed
# f    350
# t    240
# Name: Employed, dtype: int64
#
#
# CreditScore
# 0     350
# 1      59
# 2      40
# 3      23
# 6      18
# 5      15
# 4      14
# 11     13
# 7      13
# 8       9
# 9       8
# 14      8
# 10      6
# 12      5
# ...

# %%
data.drop('Key', inplace=True, axis=1)

# %%
data.head()
# Out:
#   Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    ?  40.83  3.500       u            g              i        bb
# 1    ?  32.25  1.500       u            g              c         v
# 2    ?  28.17  0.585       u            g             aa         v
# 3    ?  29.75  0.665       u            g              w         v
# 4    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#   ZipCode  Income Approved
# 0    1160       0        -
# 1     372     122        -
# ...

# %%
data.drop('ZipCode', inplace=True, axis=1)

# %%
data.head()
# Out:
#   Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    ?  40.83  3.500       u            g              i        bb
# 1    ?  32.25  1.500       u            g              c         v
# 2    ?  28.17  0.585       u            g             aa         v
# 3    ?  29.75  0.665       u            g              w         v
# 4    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#    Income Approved
# 0       0        -
# 1     122        -
# 2    1004        -
# 3       0        -
# ...

# %%
y = data[['Approved']]

# %%
X = data.drop('Approved', axis=1)

# %%
X.head()
# Out:
#   Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    ?  40.83  3.500       u            g              i        bb
# 1    ?  32.25  1.500       u            g              c         v
# 2    ?  28.17  0.585       u            g             aa         v
# 3    ?  29.75  0.665       u            g              w         v
# 4    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#    Income
# 0       0
# 1     122
# 2    1004
# 3       0
# 4       0

# %%
inapropriate_data = data.loc[data['Male'] == '?']
inapropriate_data
# Out:
#     Male    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      ?  40.83   3.500       u            g              i        bb
# 1      ?  32.25   1.500       u            g              c         v
# 2      ?  28.17   0.585       u            g             aa         v
# 3      ?  29.75   0.665       u            g              w         v
# 4      ?   26.5   2.710       y            p              ?         ?
# 5      ?  45.33   1.000       u            g              q         v
# 6      ?  42.25   1.750       y            p              ?         ?
# 7      ?  33.17   2.250       y            p             cc         v
# 484    ?   24.5  12.750       u            g              c        bb
# 530    ?  20.42   7.500       u            g              k         v
# 584    ?  20.08   0.125       u            g              q         v
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# ...

# %%
index_of_faulty_data = data.loc[data['Male'] == '?'].index.values
index_of_faulty_data
# Out:
# array([  0,   1,   2,   3,   4,   5,   6,   7, 484, 530, 584], dtype=int64)

# %%
for i in index_of_faulty_data:
    print(data.iloc[i].Male)
    data.iloc[i].Male = 'b'
# Out:
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# c:\users\prasad\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.iloc[0]['Male'] = 'b'
# Out:
# c:\users\prasad\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.iloc[0]
# Out:
# Male                  ?
# Age               40.83
# Debt                3.5
# Married               u
# BankCustomer          g
# EducationLevel        i
# Ethnicity            bb
# YearsEmployed       0.5
# PriorDefault          f
# Employed              f
# CreditScore           0
# DriversLicense        f
# Citizen               s
# Income                0
# Approved              -
# Name: 0, dtype: object

# %%
X.drop(index_of_faulty_data, inplace=True)

# %%
y.drop(index_of_faulty_data, inplace=True)
# Out:
# c:\users\prasad\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X.shape
# Out:
# (579, 14)

# %%
y.shape
# Out:
# (579, 1)

# %%
X.head()
# Out:
#    Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 8     a  38.58  5.000       u            g             cc         v
# 9     a  19.17  0.585       y            p             aa         v
# 10    a  27.67  1.500       u            g              m         v
# 11    a      ?  3.500       u            g              d         v
# 12    a     49  1.500       u            g              j         j
#
#     YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 8          13.500            t        f            0              t       g
# 9           0.585            t        f            0              t       g
# 10          2.000            t        f            0              f       s
# 11          3.000            t        f            0              t       g
# 12          0.000            t        f            0              t       g
#
#     Income
# 8        0
# 9        0
# 10       0
# 11       0
# 12      27

# %%
X.head()
# Out:
#    Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 8     a  38.58  5.000       u            g             cc         v
# 9     a  19.17  0.585       y            p             aa         v
# 10    a  27.67  1.500       u            g              m         v
# 11    a      ?  3.500       u            g              d         v
# 12    a     49  1.500       u            g              j         j
#
#     YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 8          13.500            t        f            0              t       g
# 9           0.585            t        f            0              t       g
# 10          2.000            t        f            0              f       s
# 11          3.000            t        f            0              t       g
# 12          0.000            t        f            0              t       g
#
#     Income
# 8        0
# 9        0
# 10       0
# 11       0
# 12      27

# %%
X.columns
# Out:
# Index(['Male', 'Age', 'Debt', 'Married', 'BankCustomer', 'EducationLevel',
#        'Ethnicity', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore',
#        'DriversLicense', 'Citizen', 'Income'],
#       dtype='object')

# %%
X.head()
# Out:
#    Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 8     a  38.58  5.000       u            g             cc         v
# 9     a  19.17  0.585       y            p             aa         v
# 10    a  27.67  1.500       u            g              m         v
# 11    a      ?  3.500       u            g              d         v
# 12    a     49  1.500       u            g              j         j
#
#     YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 8          13.500            t        f            0              t       g
# 9           0.585            t        f            0              t       g
# 10          2.000            t        f            0              f       s
# 11          3.000            t        f            0              t       g
# 12          0.000            t        f            0              t       g
#
#     Income
# 8        0
# 9        0
# 10       0
# 11       0
# 12      27

# %%
categorical_x = X.drop(['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'Income'], axis=1)

# %%
categorical_x.head()
# Out:
#    Male Married BankCustomer EducationLevel Ethnicity PriorDefault Employed  \
# 8     a       u            g             cc         v            t        f
# 9     a       y            p             aa         v            t        f
# 10    a       u            g              m         v            t        f
# 11    a       u            g              d         v            t        f
# 12    a       u            g              j         j            t        f
#
#    DriversLicense Citizen
# 8               t       g
# 9               t       g
# 10              f       s
# 11              t       g
# 12              t       g

# %%
clean_data = pd.get_dummies(categorical_x)

# %%
clean_data.shape
# Out:
# (579, 44)

# %%
clean_data2 = X.loc[:,['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'Income']]

# %%
clean_data2.shape
# Out:
# (579, 5)

# %%
features = pd.concat([clean_data, clean_data2], axis=1)

# %%
features.head()
# Out:
#     Male_a  Male_b  Married_?  Married_l  Married_u  Married_y  \
# 8        1       0          0          0          1          0
# 9        1       0          0          0          0          1
# 10       1       0          0          0          1          0
# 11       1       0          0          0          1          0
# 12       1       0          0          0          1          0
#
#     BankCustomer_?  BankCustomer_g  BankCustomer_gg  BankCustomer_p  ...  \
# 8                0               1                0               0  ...
# 9                0               0                0               1  ...
# 10               0               1                0               0  ...
# 11               0               1                0               0  ...
# 12               0               1                0               0  ...
#
#     DriversLicense_f  DriversLicense_t  Citizen_g  Citizen_p  Citizen_s  \
# ...

# %%
features.shape
# Out:
# (579, 49)

# %%
y.shape
# Out:
# (579, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, y, test_size=0.3)

# %%
X_train.count()
# Out:
# Male_a               405
# Male_b               405
# Married_?            405
# Married_l            405
# Married_u            405
# Married_y            405
# BankCustomer_?       405
# BankCustomer_g       405
# BankCustomer_gg      405
# BankCustomer_p       405
# EducationLevel_?     405
# EducationLevel_aa    405
# EducationLevel_c     405
# EducationLevel_cc    405
# EducationLevel_d     405
# EducationLevel_e     405
# EducationLevel_ff    405
# EducationLevel_i     405
# EducationLevel_j     405
# EducationLevel_k     405
# EducationLevel_m     405
# EducationLevel_q     405
# EducationLevel_r     405
# EducationLevel_w     405
# EducationLevel_x     405
# Ethnicity_?          405
# Ethnicity_bb         405
# Ethnicity_dd         405
# Ethnicity_ff         405
# Ethnicity_h          405
# Ethnicity_j          405
# Ethnicity_n          405
# Ethnicity_o          405
# Ethnicity_v          405
# Ethnicity_z          405
# PriorDefault_f       405
# PriorDefault_t       405
# ...

# %%
len(X_test)
# Out:
# 174

# %%
len(y_train)
# Out:
# 405

# %%
len(y_test)
# Out:
# 174

# %%
X_train.head()
# Out:
#      Male_a  Male_b  Married_?  Married_l  Married_u  Married_y  \
# 146       0       1          0          0          1          0
# 211       0       1          0          0          1          0
# 489       0       1          0          0          1          0
# 69        1       0          0          0          0          1
# 370       0       1          0          0          1          0
#
#      BankCustomer_?  BankCustomer_g  BankCustomer_gg  BankCustomer_p  ...  \
# 146               0               1                0               0  ...
# 211               0               1                0               0  ...
# 489               0               1                0               0  ...
# 69                0               0                0               1  ...
# 370               0               1                0               0  ...
#
#      DriversLicense_f  DriversLicense_t  Citizen_g  Citizen_p  Citizen_s  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_clf = LogisticRegression()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_clf = DecisionTreeClassifier(max_depth=5)

# %%
X_train.head()
# Out:
#      Male_a  Male_b  Married_?  Married_l  Married_u  Married_y  \
# 146       0       1          0          0          1          0
# 211       0       1          0          0          1          0
# 489       0       1          0          0          1          0
# 69        1       0          0          0          0          1
# 370       0       1          0          0          1          0
#
#      BankCustomer_?  BankCustomer_g  BankCustomer_gg  BankCustomer_p  ...  \
# 146               0               1                0               0  ...
# 211               0               1                0               0  ...
# 489               0               1                0               0  ...
# 69                0               0                0               1  ...
# 370               0               1                0               0  ...
#
#      DriversLicense_f  DriversLicense_t  Citizen_g  Citizen_p  Citizen_s  \
# ...

# %%
X_train.isna().any()
# Out:
# Male_a               False
# Male_b               False
# Married_?            False
# Married_l            False
# Married_u            False
# Married_y            False
# BankCustomer_?       False
# BankCustomer_g       False
# BankCustomer_gg      False
# BankCustomer_p       False
# EducationLevel_?     False
# EducationLevel_aa    False
# EducationLevel_c     False
# EducationLevel_cc    False
# EducationLevel_d     False
# EducationLevel_e     False
# EducationLevel_ff    False
# EducationLevel_i     False
# EducationLevel_j     False
# EducationLevel_k     False
# EducationLevel_m     False
# EducationLevel_q     False
# EducationLevel_r     False
# EducationLevel_w     False
# EducationLevel_x     False
# Ethnicity_?          False
# Ethnicity_bb         False
# Ethnicity_dd         False
# Ethnicity_ff         False
# Ethnicity_h          False
# Ethnicity_j          False
# Ethnicity_n          False
# Ethnicity_o          False
# Ethnicity_v          False
# ...
